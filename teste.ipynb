# %%
#Teste 1
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from Modelo import *
from Dados import *
from CPCV import *
# Modelo
# params = {"class_weight": "balanced_subsample", "criterion": "entropy", "max_features": 1, "min_weight_fraction_leaf": 0.01, "n_estimators": 1000, "random_state": 0}
# modelo = RandomForestClassifier(**params)

# # Chamando a função
# funcao_modelo = Modelo('binária')
# funcao_modelo.model(modelo=modelo,
#                     nome_modelo='RandomForestTCC',
#                     n_splits=5,
#                     n_test_splits=2)
# funcao_modelo.relatorio_model()

# %%
import plotly_express as px
import plotly.graph_objects as go
df = pd.read_csv('./relatorios/TCC_SVM/previsoes.csv')
fig = go.Figure()
#Retorno do Modelo
fig.add_traces(go.Scatter(x=df['Date'], y=df['Retorno_Acumulado_Modelo'],name='Retorno do Modelo'))
#Retorno Mercado
fig.add_traces(go.Scatter(x=df['Date'], y=df['Retorno_Acumulado_Mercado'],name='Retorno do Mercado'))
#DrawDown Modelo:
# fig.add_traces(go.Scatter(x=merge.index, y=merge['DrawDown'],name='DrawDown'))

fig.show()

# %%
from sklearn.metrics import classification_report
report = classification_report(df['y_test'],df['y_pred'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.38      0.44       525
#            1       0.54      0.68      0.60       556
#
#     accuracy                           0.53      1081
#    macro avg       0.53      0.53      0.52      1081
# weighted avg       0.53      0.53      0.52      1081
